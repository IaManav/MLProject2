# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/manavsharma/Code/PYTHON/MLProject2/notebook/data/used_cars.csv")

# %%
df.head()
# Out:
#       brand                            model  model_year      milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1   Hyundai                     Palisade SEL        2021  34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
df.shape
# Out:
# (4009, 12)

# %%
df.isna().sum()
# Out:
# brand             0
# model             0
# model_year        0
# milage            0
# fuel_type       170
# engine            0
# transmission      0
# ext_col           0
# int_col           0
# accident        113
# clean_title     596
# price             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   object
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 376.0+ KB

# %%
df.nunique()
# Out:
# brand             57
# model           1898
# model_year        34
# milage          2818
# fuel_type          7
# engine          1146
# transmission      62
# ext_col          319
# int_col          156
# accident           2
# clean_title        1
# price           1569
# dtype: int64

# %%
df.describe()
# Out:
#         model_year
# count  4009.000000
# mean   2015.515590
# std       6.104816
# min    1974.000000
# 25%    2012.000000
# 50%    2017.000000
# 75%    2020.000000
# max    2024.000000

# %%
df['price']=df['price'].str[1:]

# %%
df['price']=df['price'].str.replace(',','')

# %%
df['price']=pd.to_numeric(df['price'])

# %%
df['model_year']=pd.to_datetime(df['model_year'],format='%Y')

# %%
df['model_year']
# Out:
# 0      2013-01-01
# 1      2021-01-01
# 2      2022-01-01
# 3      2015-01-01
# 4      2021-01-01
#           ...
# 4004   2023-01-01
# 4005   2022-01-01
# 4006   2022-01-01
# 4007   2020-01-01
# 4008   2020-01-01
# Name: model_year, Length: 4009, dtype: datetime64[ns]

# %%
df.head()
# Out:
#       brand                            model model_year      milage  \
# 0      Ford  Utility Police Interceptor Base 2013-01-01  51,000 mi.
# 1   Hyundai                     Palisade SEL 2021-01-01  34,742 mi.
# 2     Lexus                    RX 350 RX 350 2022-01-01  22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport 2015-01-01  88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus 2021-01-01   9,835 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
df['milage']=pd.to_numeric((df['milage'].str.replace('mi.','')).str.replace(',',''))

# %%
df['milage']
# Out:
# 0       51000
# 1       34742
# 2       22372
# 3       88900
# 4        9835
#         ...
# 4004      714
# 4005    10900
# 4006     2116
# 4007    33000
# 4008    43000
# Name: milage, Length: 4009, dtype: int64

# %%
df['brand'].value_counts()
# Out:
# brand
# Ford             386
# BMW              375
# Mercedes-Benz    315
# Chevrolet        292
# Porsche          201
# Audi             200
# Toyota           199
# Lexus            163
# Jeep             143
# Land             130
# Nissan           116
# Cadillac         107
# GMC               91
# RAM               91
# Dodge             90
# Tesla             87
# Kia               76
# Hyundai           72
# Mazda             64
# Acura             64
# Subaru            64
# Honda             63
# Volkswagen        59
# INFINITI          59
# Lincoln           52
# Jaguar            47
# Volvo             38
# Maserati          34
# Bentley           33
# MINI              33
# Buick             30
# Chrysler          28
# Lamborghini       26
# Mitsubishi        20
# Genesis           20
# Alfa              19
# Rivian            17
# Hummer            16
# Pontiac           15
# Ferrari           12
# Rolls-Royce       11
# Aston              9
# McLaren            6
# ...

# %%
df['engine'].value_counts()[df['engine'].value_counts() == 1]
# Out:
# engine
# 4L V-6 DOHC, VVT-i variable valve control, regular unleaded, eng    1
# 192.0HP 1.5L 4 Cylinder Engine Gasoline Fuel                        1
# 416.0HP Electric Motor Electric Fuel System                         1
# 308.0HP 3.6L V6 Cylinder Engine Flex Fuel Capability                1
# 172.0HP 2.4L 4 Cylinder Engine Gas/Electric Hybrid                  1
#                                                                    ..
# 323.0HP 6.0L 8 Cylinder Engine Gasoline Fuel                        1
# 405.0HP 4.2L 8 Cylinder Engine Gasoline Fuel                        1
# 353.0HP 6.0L 8 Cylinder Engine Gasoline Fuel                        1
# 275.0HP 4.8L 8 Cylinder Engine Gasoline Fuel                        1
# 420.0HP 5.9L 12 Cylinder Engine Gasoline Fuel                       1
# Name: count, Length: 492, dtype: int64

# %%
df[df['engine'].str.contains('4 Cylinder')]
# Out:
#               brand                       model model_year  milage  \
# 6              Audi        S3 2.0T Premium Plus 2017-01-01   84000
# 21        Chevrolet                     S-10 LS 2000-01-01  133510
# 25          Hyundai              Elantra N Base 2022-01-01   11650
# 27    Mercedes-Benz      AMG CLA 45 Base 4MATIC 2021-01-01   17500
# 35             Jeep       New Compass Trailhawk 2017-01-01  119000
# ...             ...                         ...        ...     ...
# 3987            BMW                X3 xDrive28i 2015-01-01   92984
# 3995          Lexus                CT 200h Base 2016-01-01   39750
# 4000         Subaru  Ascent Touring 7-Passenger 2021-01-01   32250
# 4003  Mercedes-Benz        E-Class E 300 4MATIC 2018-01-01   53705
# 4008            BMW                X3 xDrive30i 2020-01-01   43000
#
#           fuel_type                                             engine  \
# 6          Gasoline       292.0HP 2.0L 4 Cylinder Engine Gasoline Fuel
# ...
